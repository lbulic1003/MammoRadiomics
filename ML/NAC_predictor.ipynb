# %% [markdown]
# DATA PREPROCESSING

# %%
# DEFINITIONS AND IMPORTING

import pandas as pd
import numpy as np
import scipy.stats as stats
import sklearn.feature_selection as fs
import sklearn.linear_model as lm
import sklearn.ensemble as se
import sklearn.metrics as sm
import sklearn.model_selection as sms
import sklearn.neighbors as sn
import xgboost as xgb
import matplotlib.pyplot as pyplt
import boruta as bt
import catboost as cb
import optuna
from IPython.display import clear_output
import warnings
import pickle
import shap
import os
warnings.simplefilter('ignore')
np.random.seed(42)

np.int = np.int64
np.float = np.float64
np.bool = np.bool_

SKF = sms.StratifiedKFold(n_splits=5, random_state=42, shuffle=True)

clear_output()

# %%
# DATA LOADING

def process_data(data_X):

    derived_keys = ["native", "1_pc", "2_pc", "3_pc", "4_pc", "5_pc"]
    load_X = data_X.copy()

    df_derived = pd.concat([load_X[key] for key in derived_keys])
    load_X["feat_mean"] = df_derived.groupby(df_derived.index).mean()
    load_X["feat_max_diff"] = df_derived.groupby(df_derived.index).max() - df_derived.groupby(df_derived.index).min()
    load_X["feat_std"] = df_derived.groupby(df_derived.index).std()
    load_X["feat_max"] = df_derived.groupby(df_derived.index).max()
    load_X["feat_min"] = df_derived.groupby(df_derived.index).min()

    keys = derived_keys.copy()
    added_keys = ["feat_mean", "feat_max_diff", "feat_std", "feat_max", "feat_min"]
    keys += added_keys

    concat_X = {}

    for i in keys:
        concat_X[i] = load_X[i].add_suffix(f"_{i}")

    return_X = pd.concat(concat_X.values(), axis=1)

    return return_X

db_1 = pd.read_pickle("data/database_1_X.pkl")
for i in db_1.keys():
    db_1[i].reset_index(inplace=True)
    ind = db_1[i]["seg_name"]
    db_1[i].drop("seg_name", axis=1, inplace=True)

X_all = process_data(db_1)
X_native = db_1["native"].copy()

print(X_all.shape)
print(X_native.shape)

db_y = pd.read_csv("data/database_1_y.csv")
y_all = db_y.drop("seg_name", axis=1)
# Out:
# (158, 19591)
# (158, 1781)

# %% [markdown]
# ML PIPELINE

# %%
def RandomForestClassifier_trial_data(trial):
  return {"n_estimators" : trial.suggest_int("n_estimators", 10, 4000, log=True),
            "max_depth" : trial.suggest_int("max_depth", 1, 20),
            "min_samples_split" : trial.suggest_int("min_samples_split", 2, 20),
            "min_samples_leaf" : trial.suggest_int("min_samples_leaf", 1, 20),
            "max_leaf_nodes" : trial.suggest_int("max_leaf_nodes", 2, 20),
            "min_impurity_decrease" : trial.suggest_float("min_impurity_decrease", 0, 0.1),
            "min_weight_fraction_leaf" : trial.suggest_float("min_weight_fraction_leaf", 0, 0.5),
            "random_state" : trial.suggest_categorical("random_state", [42]),
            "max_features" : trial.suggest_categorical("max_features", ["sqrt", "log2", None]),
            "bootstrap" : trial.suggest_categorical("bootstrap", [True, False])}

def XGBoostClassifier_trial_data(trial):
  return {"booster" : "gbtree",
            "n_estimators" : trial.suggest_int("n_estimators", 10, 4000, log=True),
            "max_depth" : trial.suggest_int("max_depth", 1, 20),
            "max_delta_step" : trial.suggest_float("max_delta_step", 0, 10),
            "learning_rate" : trial.suggest_float("learning_rate", 0.05, 1, log=True),
            "alpha" : trial.suggest_float("alpha", 0.01, 100, log=True),
            "gamma" : trial.suggest_float("gamma", 0.01, 1, log=True),
            "lambda" : trial.suggest_float("lambda", 0.01, 100, log=True),
            "colsample_bytree" : trial.suggest_float("colsample_bytree", 0.1, 1),
            "colsample_bylevel" : trial.suggest_float("colsample_bylevel", 0.1, 1),
            "random_state" : trial.suggest_categorical("random_state", [42])}

def CatBoostClassifier_trial_data(trial):
  return {"iterations" : trial.suggest_int("iterations", 50, 500, log=True),
          "learning_rate" : trial.suggest_float("learning_rate", 0.005, 1, log=True),
           "depth" : trial.suggest_int("depth", 1, 10),
           "min_data_in_leaf" : trial.suggest_int("min_data_in_leaf", 1, 150),
           "random_state" : trial.suggest_categorical("random_state", [42]),
           "colsample_bylevel" : trial.suggest_float("colsample_bylevel", 0.1, 1)}

def RidgeLogistic_trial_data(trial):
    return {"penalty" : trial.suggest_categorical("penalty", ["l2"]),
            "random_state" : trial.suggest_categorical("random_state", [42]),
            "solver" : trial.suggest_categorical("solver", ["liblinear", "saga"]),
            "max_iter" : trial.suggest_int("max_iter", 100, 3000),
            "C" : trial.suggest_float("C", 0.01, 1)}

def optuna_trial_hyperparametrized(trial, model_name):
  match model_name:
    case "RandomForestClassifier":
      return se.RandomForestClassifier(**(RandomForestClassifier_trial_data(trial)))
    case "XGBoostClassifier":
      return xgb.XGBClassifier(**(XGBoostClassifier_trial_data(trial)))
    case "CatBoostClassifier":
      return cb.CatBoostClassifier(**(CatBoostClassifier_trial_data(trial)))
    case "RidgeLogistic":
      return lm.LogisticRegression(**(RidgeLogistic_trial_data(trial)))
  return None

def optuna_result_hyperparametrized(params, model_name):
  match model_name:
    case "RandomForestClassifier":
      return se.RandomForestClassifier(**params)
    case "XGBoostClassifier":
      return xgb.XGBClassifier(**params)
    case "CatBoostClassifier":
      return cb.CatBoostClassifier(**params)
    case "RidgeLogistic":
        return lm.LogisticRegression(**params)
  return None

def hyperparameter_optimization(X, y, model_name):
  def objective(trial):
    model = optuna_trial_hyperparametrized(trial, model_name)
    scores = sms.cross_validate(model, X, y, cv=SKF, scoring=("accuracy", "f1", "roc_auc"), n_jobs=-1)
    return (np.mean(scores["test_accuracy"]) + np.mean(scores["test_f1"]) + 5*np.mean(scores["test_roc_auc"]))        
  study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=42))
  study.optimize(objective, n_trials=50, n_jobs=-1)
  return study.best_params

def feature_selection(X, y, mode):
  if(mode=="kbest"):
    fs_kbest = fs.SelectKBest(fs.mutual_info_classif, k=1000).fit(X, y)
    return list(fs_kbest.get_feature_names_out())
  elif(mode=="boruta"):
    fs_kbest = fs.SelectKBest(fs.mutual_info_classif, k=5000).fit(X, y)
    sel_feat_mutual = list(fs_kbest.get_feature_names_out())
    X_fs = X[sel_feat_mutual]
    X_fs = X.copy()
    hyperparameters = hyperparameter_optimization(X_fs, y, "XGBoostClassifier")
    fs_estimator = optuna_result_hyperparametrized(hyperparameters, "XGBoostClassifier")
    fs_boruta = bt.BorutaPy(fs_estimator, n_estimators="auto", verbose=2, random_state=42, perc=80).fit(X_fs.to_numpy(), y.to_numpy())
    return list(X_fs.columns[fs_boruta.support_ | fs_boruta.support_weak_])

# %%
def pipeline(X, y, model_name, ttype, mode):

    train_X, test_X, train_y, test_y = sms.train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

    feature_file = f"features/selected_features_{ttype}_{mode}.pkl"
    if(os.path.isfile(feature_file) == False):
        selected_features = feature_selection(train_X, train_y, mode)
        output = open(feature_file, "wb")
        pickle.dump(selected_features, output)
        output.close()
    selected_features = pd.read_pickle(feature_file)
    train_X = train_X[selected_features]
    test_X = test_X[selected_features]

    param_file = f"hyperparameters/hyperparameters_{model_name}_{ttype}_{mode}.pkl"
    if(os.path.isfile(param_file) == False):
        hyperparameters = hyperparameter_optimization(train_X, train_y, model_name)
        output = open(param_file, "wb")
        pickle.dump(hyperparameters, output)
        output.close()
    hyperparameters = pd.read_pickle(param_file)
    model = optuna_result_hyperparametrized(hyperparameters, model_name)

    model.fit(train_X, train_y)
    pred_y = model.predict(test_X)
    prob_y = model.predict_proba(test_X)

    accuracy = round(sm.accuracy_score(test_y, pred_y), 2)
    f1 = round(sm.f1_score(test_y, pred_y), 2)
    roc_auc = round(sm.roc_auc_score(test_y, prob_y[:,1]), 2)

    clear_output()
    
    print(f"Accuracy = {accuracy}")
    print(f"F1 = {f1}")
    print(f"ROC_AUC = {roc_auc}")

    full_model = optuna_result_hyperparametrized(hyperparameters, model_name)
    full_model.fit(X, y)
    output = open(f"models/model_{model_name}_{ttype}_{mode}.pkl", "wb")
    pickle.dump(full_model, output)
    output.close()

    return

# %% [markdown]
# MODELLING - ALL CONTRASTS

# %%
pipeline(X_all, y_all, "RandomForestClassifier", "all", "kbest")
# Out:
# Accuracy = 0.66
# F1 = 0.42
# ROC_AUC = 0.71

# %%
pipeline(X_all, y_all, "XGBoostClassifier", "all", "kbest")
# Out:
# Accuracy = 0.66
# F1 = 0.42
# ROC_AUC = 0.66

# %%
pipeline(X_all, y_all, "CatBoostClassifier", "all", "kbest")
# Out:
# Accuracy = 0.62
# F1 = 0.33
# ROC_AUC = 0.61
# 0:	learn: 0.6234786	total: 42.4ms	remaining: 2.71s
# 1:	learn: 0.5808254	total: 70.8ms	remaining: 2.23s
# 2:	learn: 0.5515578	total: 103ms	remaining: 2.12s
# 3:	learn: 0.5295154	total: 122ms	remaining: 1.86s
# 4:	learn: 0.5125164	total: 166ms	remaining: 1.99s
# 5:	learn: 0.4951993	total: 189ms	remaining: 1.86s
# 6:	learn: 0.4700395	total: 227ms	remaining: 1.88s
# 7:	learn: 0.4443500	total: 274ms	remaining: 1.95s
# 8:	learn: 0.4144655	total: 303ms	remaining: 1.88s
# 9:	learn: 0.3987232	total: 335ms	remaining: 1.84s
# 10:	learn: 0.3923176	total: 367ms	remaining: 1.8s
# 11:	learn: 0.3686563	total: 395ms	remaining: 1.74s
# 12:	learn: 0.3476891	total: 426ms	remaining: 1.7s
# 13:	learn: 0.3284073	total: 457ms	remaining: 1.67s
# 14:	learn: 0.3095940	total: 492ms	remaining: 1.64s
# 15:	learn: 0.2929548	total: 520ms	remaining: 1.59s
# 16:	learn: 0.2726355	total: 554ms	remaining: 1.56s
# 17:	learn: 0.2566292	total: 587ms	remaining: 1.53s
# 18:	learn: 0.2432831	total: 618ms	remaining: 1.5s
# 19:	learn: 0.2281460	total: 638ms	remaining: 1.44s
# 20:	learn: 0.2181601	total: 663ms	remaining: 1.39s
# 21:	learn: 0.2091580	total: 685ms	remaining: 1.34s
# 22:	learn: 0.2031205	total: 711ms	remaining: 1.3s
# 23:	learn: 0.1906466	total: 742ms	remaining: 1.27s
# 24:	learn: 0.1823556	total: 767ms	remaining: 1.23s
# 25:	learn: 0.1726714	total: 793ms	remaining: 1.19s
# 26:	learn: 0.1616799	total: 828ms	remaining: 1.17s
# 27:	learn: 0.1547698	total: 860ms	remaining: 1.14s
# 28:	learn: 0.1522749	total: 897ms	remaining: 1.11s
# 29:	learn: 0.1500555	total: 928ms	remaining: 1.08s
# 30:	learn: 0.1423953	total: 951ms	remaining: 1.04s
# 31:	learn: 0.1354448	total: 980ms	remaining: 1.01s
# 32:	learn: 0.1309703	total: 1s	remaining: 975ms
# 33:	learn: 0.1226525	total: 1.03s	remaining: 936ms
# 34:	learn: 0.1150165	total: 1.05s	remaining: 904ms
# 35:	learn: 0.1083394	total: 1.08s	remaining: 869ms
# 36:	learn: 0.1078735	total: 1.1s	remaining: 835ms
# 37:	learn: 0.1020648	total: 1.13s	remaining: 799ms
# 38:	learn: 0.0961268	total: 1.15s	remaining: 764ms
# 39:	learn: 0.0944542	total: 1.17s	remaining: 732ms
# 40:	learn: 0.0901962	total: 1.2s	remaining: 701ms
# 41:	learn: 0.0876940	total: 1.22s	remaining: 670ms
# 42:	learn: 0.0828946	total: 1.25s	remaining: 639ms
# 43:	learn: 0.0800691	total: 1.28s	remaining: 614ms
# 44:	learn: 0.0776453	total: 1.31s	remaining: 583ms
# 45:	learn: 0.0755277	total: 1.35s	remaining: 558ms
# 46:	learn: 0.0741156	total: 1.38s	remaining: 527ms
# 47:	learn: 0.0725976	total: 1.41s	remaining: 499ms
# 48:	learn: 0.0700864	total: 1.44s	remaining: 469ms
# 49:	learn: 0.0676405	total: 1.5s	remaining: 449ms
# 50:	learn: 0.0668998	total: 1.54s	remaining: 422ms
# 51:	learn: 0.0649631	total: 1.57s	remaining: 392ms
# 52:	learn: 0.0646211	total: 1.6s	remaining: 362ms
# 53:	learn: 0.0632868	total: 1.63s	remaining: 333ms
# 54:	learn: 0.0628432	total: 1.67s	remaining: 303ms
# 55:	learn: 0.0601224	total: 1.69s	remaining: 272ms
# 56:	learn: 0.0586279	total: 1.72s	remaining: 241ms
# 57:	learn: 0.0580212	total: 1.74s	remaining: 210ms
# 58:	learn: 0.0570571	total: 1.76s	remaining: 179ms
# 59:	learn: 0.0550938	total: 1.79s	remaining: 149ms
# 60:	learn: 0.0523025	total: 1.81s	remaining: 119ms
# 61:	learn: 0.0515365	total: 1.84s	remaining: 88.9ms
# 62:	learn: 0.0509563	total: 1.88s	remaining: 59.7ms
# 63:	learn: 0.0492887	total: 1.93s	remaining: 30.1ms
# 64:	learn: 0.0472903	total: 1.95s	remaining: 0us

# %%
pipeline(X_all, y_all, "RidgeLogistic", "all", "kbest")
# Out:
# Accuracy = 0.62
# F1 = 0.5
# ROC_AUC = 0.65

# %% [markdown]
# MODELING - NATIVE CONTRAST

# %%
pipeline(X_native, y_all, "RandomForestClassifier", "native", "kbest")
# Out:
# Accuracy = 0.62
# F1 = 0.45
# ROC_AUC = 0.58

# %%
pipeline(X_native, y_all, "XGBoostClassifier", "native", "kbest")
# Out:
# Accuracy = 0.62
# F1 = 0.25
# ROC_AUC = 0.55

# %%
pipeline(X_native, y_all, "CatBoostClassifier", "native", "kbest")
# Out:
# Accuracy = 0.66
# F1 = 0.27
# ROC_AUC = 0.69
# 0:	learn: 0.5940225	total: 1.9s	remaining: 8m 52s
# 1:	learn: 0.5140951	total: 3.89s	remaining: 9m 3s
# 2:	learn: 0.4568060	total: 5.83s	remaining: 9m
# 3:	learn: 0.4068264	total: 7.72s	remaining: 8m 54s
# 4:	learn: 0.3715307	total: 9.6s	remaining: 8m 50s
# 5:	learn: 0.3342566	total: 11.4s	remaining: 8m 44s
# 6:	learn: 0.3019071	total: 13.3s	remaining: 8m 41s
# 7:	learn: 0.2621875	total: 15.2s	remaining: 8m 38s
# 145:	learn: 0.0042148	total: 4m 49s	remaining: 4m 27s
# 146:	learn: 0.0041921	total: 4m 51s	remaining: 4m 25s
# 147:	learn: 0.0041620	total: 4m 53s	remaining: 4m 23s
# 148:	learn: 0.0041221	total: 4m 55s	remaining: 4m 22s
# 149:	learn: 0.0040883	total: 4m 58s	remaining: 4m 20s
# 150:	learn: 0.0040413	total: 5m	remaining: 4m 18s
# 151:	learn: 0.0040020	total: 5m 2s	remaining: 4m 16s
# 152:	learn: 0.0039595	total: 5m 3s	remaining: 4m 14s
# 153:	learn: 0.0039259	total: 5m 5s	remaining: 4m 11s
# 154:	learn: 0.0038868	total: 5m 6s	remaining: 4m 9s
# 155:	learn: 0.0038526	total: 5m 8s	remaining: 4m 7s
# 156:	learn: 0.0038052	total: 5m 10s	remaining: 4m 4s
# 157:	learn: 0.0037887	total: 5m 11s	remaining: 4m 2s
# 158:	learn: 0.0037568	total: 5m 13s	remaining: 4m
# 159:	learn: 0.0037323	total: 5m 15s	remaining: 3m 58s
# 160:	learn: 0.0037081	total: 5m 16s	remaining: 3m 56s
# 161:	learn: 0.0036853	total: 5m 18s	remaining: 3m 54s
# 162:	learn: 0.0036609	total: 5m 20s	remaining: 3m 52s
# 163:	learn: 0.0036373	total: 5m 22s	remaining: 3m 50s
# 164:	learn: 0.0036223	total: 5m 24s	remaining: 3m 47s
# 165:	learn: 0.0035922	total: 5m 25s	remaining: 3m 45s
# 166:	learn: 0.0035634	total: 5m 27s	remaining: 3m 43s
# 167:	learn: 0.0035375	total: 5m 28s	remaining: 3m 41s
# 168:	learn: 0.0035160	total: 5m 30s	remaining: 3m 39s
# 169:	learn: 0.0034914	total: 5m 32s	remaining: 3m 36s
# 170:	learn: 0.0034646	total: 5m 34s	remaining: 3m 35s
# 171:	learn: 0.0034448	total: 5m 36s	remaining: 3m 33s
# 172:	learn: 0.0034214	total: 5m 38s	remaining: 3m 31s
# 173:	learn: 0.0034020	total: 5m 40s	remaining: 3m 29s
# 174:	learn: 0.0033794	total: 5m 42s	remaining: 3m 27s
# 175:	learn: 0.0033610	total: 5m 44s	remaining: 3m 25s
# 176:	learn: 0.0033357	total: 5m 48s	remaining: 3m 24s
# 177:	learn: 0.0033189	total: 5m 50s	remaining: 3m 23s
# 178:	learn: 0.0033082	total: 5m 53s	remaining: 3m 21s
# 179:	learn: 0.0032778	total: 5m 55s	remaining: 3m 19s
# 180:	learn: 0.0032537	total: 5m 57s	remaining: 3m 17s
# 181:	learn: 0.0032371	total: 5m 59s	remaining: 3m 15s
# 182:	learn: 0.0032221	total: 6m 2s	remaining: 3m 13s
# 183:	learn: 0.0031940	total: 6m 3s	remaining: 3m 11s
# 184:	learn: 0.0031817	total: 6m 5s	remaining: 3m 9s
# 185:	learn: 0.0031397	total: 6m 7s	remaining: 3m 7s
# 186:	learn: 0.0031248	total: 6m 9s	remaining: 3m 5s
# 187:	learn: 0.0031057	total: 6m 10s	remaining: 3m 3s
# 188:	learn: 0.0030916	total: 6m 13s	remaining: 3m 1s
# 189:	learn: 0.0030652	total: 6m 15s	remaining: 2m 59s
# 190:	learn: 0.0030357	total: 6m 17s	remaining: 2m 57s
# 191:	learn: 0.0030231	total: 6m 19s	remaining: 2m 56s
# 192:	learn: 0.0030042	total: 6m 22s	remaining: 2m 54s
# 193:	learn: 0.0029901	total: 6m 24s	remaining: 2m 52s
# 194:	learn: 0.0029768	total: 6m 25s	remaining: 2m 50s
# 195:	learn: 0.0029647	total: 6m 27s	remaining: 2m 48s
# 196:	learn: 0.0029534	total: 6m 29s	remaining: 2m 46s
# 197:	learn: 0.0029263	total: 6m 31s	remaining: 2m 44s
# 198:	learn: 0.0029148	total: 6m 33s	remaining: 2m 42s
# 199:	learn: 0.0028953	total: 6m 35s	remaining: 2m 40s
# 200:	learn: 0.0028825	total: 6m 37s	remaining: 2m 38s
# 201:	learn: 0.0028686	total: 6m 39s	remaining: 2m 36s
# 202:	learn: 0.0028556	total: 6m 41s	remaining: 2m 34s
# 203:	learn: 0.0028363	total: 6m 43s	remaining: 2m 32s
# 204:	learn: 0.0028143	total: 6m 45s	remaining: 2m 30s
# 205:	learn: 0.0027986	total: 6m 48s	remaining: 2m 28s
# 206:	learn: 0.0027829	total: 6m 50s	remaining: 2m 26s
# 207:	learn: 0.0027587	total: 6m 52s	remaining: 2m 24s
# 208:	learn: 0.0027401	total: 6m 54s	remaining: 2m 22s
# 209:	learn: 0.0027275	total: 6m 56s	remaining: 2m 20s
# 210:	learn: 0.0027058	total: 6m 58s	remaining: 2m 18s
# 211:	learn: 0.0026818	total: 7m	remaining: 2m 16s
# 212:	learn: 0.0026718	total: 7m 2s	remaining: 2m 14s
# 213:	learn: 0.0026544	total: 7m 4s	remaining: 2m 13s
# 214:	learn: 0.0026332	total: 7m 7s	remaining: 2m 11s
# 215:	learn: 0.0026217	total: 7m 9s	remaining: 2m 9s
# 216:	learn: 0.0026036	total: 7m 11s	remaining: 2m 7s
# 217:	learn: 0.0025942	total: 7m 13s	remaining: 2m 5s
# 218:	learn: 0.0025763	total: 7m 15s	remaining: 2m 3s
# 219:	learn: 0.0025631	total: 7m 16s	remaining: 2m 1s
# 220:	learn: 0.0025477	total: 7m 18s	remaining: 1m 59s
# 221:	learn: 0.0025345	total: 7m 20s	remaining: 1m 57s
# 222:	learn: 0.0025186	total: 7m 22s	remaining: 1m 55s
# 223:	learn: 0.0025040	total: 7m 24s	remaining: 1m 52s
# 224:	learn: 0.0024943	total: 7m 25s	remaining: 1m 50s
# 225:	learn: 0.0024779	total: 7m 27s	remaining: 1m 48s
# 226:	learn: 0.0024614	total: 7m 29s	remaining: 1m 46s
# 227:	learn: 0.0024486	total: 7m 31s	remaining: 1m 44s
# 228:	learn: 0.0024405	total: 7m 32s	remaining: 1m 42s
# 229:	learn: 0.0024295	total: 7m 34s	remaining: 1m 40s
# 230:	learn: 0.0024225	total: 7m 35s	remaining: 1m 38s
# 231:	learn: 0.0024094	total: 7m 37s	remaining: 1m 36s
# 232:	learn: 0.0024031	total: 7m 39s	remaining: 1m 34s
# 233:	learn: 0.0023913	total: 7m 41s	remaining: 1m 32s
# 234:	learn: 0.0023773	total: 7m 43s	remaining: 1m 30s
# 235:	learn: 0.0023705	total: 7m 44s	remaining: 1m 28s
# 236:	learn: 0.0023617	total: 7m 46s	remaining: 1m 26s
# 237:	learn: 0.0023456	total: 7m 47s	remaining: 1m 24s
# 238:	learn: 0.0023364	total: 7m 49s	remaining: 1m 22s
# 239:	learn: 0.0023279	total: 7m 51s	remaining: 1m 20s
# 240:	learn: 0.0023133	total: 7m 52s	remaining: 1m 18s
# 241:	learn: 0.0023043	total: 7m 54s	remaining: 1m 16s
# 242:	learn: 0.0022979	total: 7m 56s	remaining: 1m 14s
# 243:	learn: 0.0022878	total: 7m 57s	remaining: 1m 12s
# 244:	learn: 0.0022690	total: 7m 59s	remaining: 1m 10s
# 245:	learn: 0.0022578	total: 8m 1s	remaining: 1m 8s
# 246:	learn: 0.0022474	total: 8m 3s	remaining: 1m 6s
# 247:	learn: 0.0022379	total: 8m 4s	remaining: 1m 4s
# 248:	learn: 0.0022260	total: 8m 6s	remaining: 1m 2s
# 249:	learn: 0.0022138	total: 8m 8s	remaining: 1m
# 250:	learn: 0.0022061	total: 8m 11s	remaining: 58.7s
# 251:	learn: 0.0021946	total: 8m 12s	remaining: 56.7s
# 252:	learn: 0.0021860	total: 8m 15s	remaining: 54.8s
# 253:	learn: 0.0021759	total: 8m 17s	remaining: 52.9s
# 254:	learn: 0.0021641	total: 8m 18s	remaining: 50.9s
# 255:	learn: 0.0021506	total: 8m 20s	remaining: 48.9s
# 256:	learn: 0.0021462	total: 8m 22s	remaining: 46.9s
# 257:	learn: 0.0021400	total: 8m 23s	remaining: 44.9s
# 258:	learn: 0.0021278	total: 8m 24s	remaining: 42.9s
# 259:	learn: 0.0021190	total: 8m 26s	remaining: 40.9s
# 260:	learn: 0.0021110	total: 8m 28s	remaining: 39s
# 261:	learn: 0.0021031	total: 8m 29s	remaining: 37s
# 262:	learn: 0.0020948	total: 8m 31s	remaining: 35s
# 263:	learn: 0.0020844	total: 8m 33s	remaining: 33.1s
# 264:	learn: 0.0020766	total: 8m 35s	remaining: 31.1s
# 265:	learn: 0.0020624	total: 8m 37s	remaining: 29.2s
# 266:	learn: 0.0020543	total: 8m 38s	remaining: 27.2s
# 267:	learn: 0.0020462	total: 8m 40s	remaining: 25.2s
# 268:	learn: 0.0020386	total: 8m 42s	remaining: 23.3s
# 269:	learn: 0.0020330	total: 8m 44s	remaining: 21.4s
# 270:	learn: 0.0020267	total: 8m 46s	remaining: 19.4s
# 271:	learn: 0.0020180	total: 8m 48s	remaining: 17.5s
# 272:	learn: 0.0020097	total: 8m 51s	remaining: 15.6s
# 273:	learn: 0.0020029	total: 8m 53s	remaining: 13.6s
# 274:	learn: 0.0019926	total: 8m 55s	remaining: 11.7s
# 275:	learn: 0.0019778	total: 8m 57s	remaining: 9.74s
# 276:	learn: 0.0019673	total: 8m 59s	remaining: 7.79s
# 277:	learn: 0.0019611	total: 9m 1s	remaining: 5.85s
# 278:	learn: 0.0019537	total: 9m 3s	remaining: 3.89s
# 279:	learn: 0.0019446	total: 9m 4s	remaining: 1.95s
# 280:	learn: 0.0019352	total: 9m 6s	remaining: 0us

# %%
pipeline(X_native, y_all, "RidgeLogistic", "native", "kbest")
# Out:
# Accuracy = 0.66
# F1 = 0.35
# ROC_AUC = 0.62
