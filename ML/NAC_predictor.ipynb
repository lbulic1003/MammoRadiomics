# %% [markdown]
# DATA PREPROCESSING

# %%
# DEFINITIONS AND IMPORTING

import pandas as pd
import numpy as np
import scipy.stats as stats
import sklearn.feature_selection as fs
import sklearn.linear_model as lm
import sklearn.ensemble as se
import sklearn.metrics as sm
import sklearn.model_selection as sms
import sklearn.neighbors as sn
import xgboost as xgb
import matplotlib.pyplot as pyplt
import boruta as bt
import catboost as cb
import optuna
from IPython.display import clear_output
import warnings
import pickle
import shap
import os
warnings.simplefilter('ignore')
np.random.seed(42)

np.int = np.int64
np.float = np.float64
np.bool = np.bool_

SKF = sms.StratifiedKFold(n_splits=5, random_state=42, shuffle=True)

clear_output()

# %%
# DATA LOADING

def process_data(data_X):

    derived_keys = ["native", "1_pc", "2_pc", "3_pc", "4_pc", "5_pc"]
    load_X = data_X.copy()

    df_derived = pd.concat([load_X[key] for key in derived_keys])
    load_X["feat_mean"] = df_derived.groupby(df_derived.index).mean()
    load_X["feat_max_diff"] = df_derived.groupby(df_derived.index).max() - df_derived.groupby(df_derived.index).min()
    load_X["feat_std"] = df_derived.groupby(df_derived.index).std()
    load_X["feat_max"] = df_derived.groupby(df_derived.index).max()
    load_X["feat_min"] = df_derived.groupby(df_derived.index).min()

    keys = derived_keys.copy()
    added_keys = ["feat_mean", "feat_max_diff", "feat_std", "feat_max", "feat_min"]
    keys += added_keys

    concat_X = {}

    for i in keys:
        concat_X[i] = load_X[i].add_suffix(f"_{i}")

    return_X = pd.concat(concat_X.values(), axis=1)

    return return_X

db_1 = pd.read_pickle("data/database_1_X.pkl")
for i in db_1.keys():
    db_1[i].reset_index(inplace=True)
    ind = db_1[i]["seg_name"]
    db_1[i].drop("seg_name", axis=1, inplace=True)

X_all = process_data(db_1)
X_native = db_1["native"].copy()

print(X_all.shape)
print(X_native.shape)

db_y = pd.read_csv("data/database_1_y.csv")
y_all = db_y.drop("seg_name", axis=1)
# Out:
# (158, 19591)
# (158, 1781)

# %% [markdown]
# ML PIPELINE

# %%
def RandomForestClassifier_trial_data(trial):
  return {"n_estimators" : trial.suggest_int("n_estimators", 10, 4000, log=True),
            "max_depth" : trial.suggest_int("max_depth", 1, 20),
            "min_samples_split" : trial.suggest_int("min_samples_split", 2, 20),
            "min_samples_leaf" : trial.suggest_int("min_samples_leaf", 1, 20),
            "max_leaf_nodes" : trial.suggest_int("max_leaf_nodes", 2, 20),
            "min_impurity_decrease" : trial.suggest_float("min_impurity_decrease", 0, 0.1),
            "min_weight_fraction_leaf" : trial.suggest_float("min_weight_fraction_leaf", 0, 0.5),
            "random_state" : trial.suggest_categorical("random_state", [42]),
            "max_features" : trial.suggest_categorical("max_features", ["sqrt", "log2", None]),
            "bootstrap" : trial.suggest_categorical("bootstrap", [True, False])}

def XGBoostClassifier_trial_data(trial):
  return {"booster" : "gbtree",
            "n_estimators" : trial.suggest_int("n_estimators", 10, 4000, log=True),
            "max_depth" : trial.suggest_int("max_depth", 1, 20),
            "max_delta_step" : trial.suggest_float("max_delta_step", 0, 10),
            "learning_rate" : trial.suggest_float("learning_rate", 0.05, 1, log=True),
            "alpha" : trial.suggest_float("alpha", 0.01, 100, log=True),
            "gamma" : trial.suggest_float("gamma", 0.01, 1, log=True),
            "lambda" : trial.suggest_float("lambda", 0.01, 100, log=True),
            "colsample_bytree" : trial.suggest_float("colsample_bytree", 0.1, 1),
            "colsample_bylevel" : trial.suggest_float("colsample_bylevel", 0.1, 1),
            "random_state" : trial.suggest_categorical("random_state", [42])}

def CatBoostClassifier_trial_data(trial):
  return {"iterations" : trial.suggest_int("iterations", 50, 500, log=True),
          "learning_rate" : trial.suggest_float("learning_rate", 0.005, 1, log=True),
           "depth" : trial.suggest_int("depth", 1, 10),
           "min_data_in_leaf" : trial.suggest_int("min_data_in_leaf", 1, 150),
           "random_state" : trial.suggest_categorical("random_state", [42]),
           "colsample_bylevel" : trial.suggest_float("colsample_bylevel", 0.1, 1)}

def RidgeLogistic_trial_data(trial):
    return {"penalty" : trial.suggest_categorical("penalty", ["l2"]),
            "random_state" : trial.suggest_categorical("random_state", [42]),
            "solver" : trial.suggest_categorical("solver", ["liblinear", "saga"]),
            "max_iter" : trial.suggest_int("max_iter", 100, 3000),
            "C" : trial.suggest_float("C", 0.01, 1)}

def optuna_trial_hyperparametrized(trial, model_name):
  match model_name:
    case "RandomForestClassifier":
      return se.RandomForestClassifier(**(RandomForestClassifier_trial_data(trial)))
    case "XGBoostClassifier":
      return xgb.XGBClassifier(**(XGBoostClassifier_trial_data(trial)))
    case "CatBoostClassifier":
      return cb.CatBoostClassifier(**(CatBoostClassifier_trial_data(trial)))
    case "RidgeLogistic":
      return lm.LogisticRegression(**(RidgeLogistic_trial_data(trial)))
  return None

def optuna_result_hyperparametrized(params, model_name):
  match model_name:
    case "RandomForestClassifier":
      return se.RandomForestClassifier(**params)
    case "XGBoostClassifier":
      return xgb.XGBClassifier(**params)
    case "CatBoostClassifier":
      return cb.CatBoostClassifier(**params)
    case "RidgeLogistic":
        return lm.LogisticRegression(**params)
  return None

def hyperparameter_optimization(X, y, model_name):
  def objective(trial):
    model = optuna_trial_hyperparametrized(trial, model_name)
    scores = sms.cross_validate(model, X, y, cv=SKF, scoring=("accuracy", "f1", "roc_auc"), n_jobs=-1)
    return (np.mean(scores["test_accuracy"]) + np.mean(scores["test_f1"]) + 5*np.mean(scores["test_roc_auc"]))        
  study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=42))
  study.optimize(objective, n_trials=50, n_jobs=-1)
  return study.best_params

def feature_selection(X, y, mode):
  if(mode=="kbest"):
    fs_kbest = fs.SelectKBest(fs.mutual_info_classif, k=1000).fit(X, y)
    return list(fs_kbest.get_feature_names_out())
  elif(mode=="boruta"):
    fs_kbest = fs.SelectKBest(fs.mutual_info_classif, k=5000).fit(X, y)
    sel_feat_mutual = list(fs_kbest.get_feature_names_out())
    X_fs = X[sel_feat_mutual]
    X_fs = X.copy()
    hyperparameters = hyperparameter_optimization(X_fs, y, "XGBoostClassifier")
    fs_estimator = optuna_result_hyperparametrized(hyperparameters, "XGBoostClassifier")
    fs_boruta = bt.BorutaPy(fs_estimator, n_estimators="auto", verbose=2, random_state=42, perc=80).fit(X_fs.to_numpy(), y.to_numpy())
    return list(X_fs.columns[fs_boruta.support_ | fs_boruta.support_weak_])

# %%
def pipeline(X, y, model_name, ttype, mode):

    train_X, test_X, train_y, test_y = sms.train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

    feature_file = f"features/selected_features_{ttype}_{mode}.pkl"
    if(os.path.isfile(feature_file) == False):
        selected_features = feature_selection(train_X, train_y, mode)
        output = open(feature_file, "wb")
        pickle.dump(selected_features, output)
        output.close()
    selected_features = pd.read_pickle(feature_file)
    train_X = train_X[selected_features]
    test_X = test_X[selected_features]

    param_file = f"hyperparameters/hyperparameters_{model_name}_{ttype}_{mode}.pkl"
    if(os.path.isfile(param_file) == False):
        hyperparameters = hyperparameter_optimization(train_X, train_y, model_name)
        output = open(param_file, "wb")
        pickle.dump(hyperparameters, output)
        output.close()
    hyperparameters = pd.read_pickle(param_file)
    model = optuna_result_hyperparametrized(hyperparameters, model_name)

    model.fit(train_X, train_y)
    pred_y = model.predict(test_X)
    prob_y = model.predict_proba(test_X)

    accuracy = round(sm.accuracy_score(test_y, pred_y), 2)
    f1 = round(sm.f1_score(test_y, pred_y), 2)
    roc_auc = round(sm.roc_auc_score(test_y, prob_y[:,1]), 2)

    clear_output()
    
    print(f"Accuracy = {accuracy}")
    print(f"F1 = {f1}")
    print(f"ROC_AUC = {roc_auc}")

    full_model = optuna_result_hyperparametrized(hyperparameters, model_name)
    full_model.fit(X[selected_features], y)
    output = open(f"models/model_{model_name}_{ttype}_{mode}.pkl", "wb")
    pickle.dump(full_model, output)
    output.close()

    return

# %% [markdown]
# MODELLING - ALL CONTRASTS

# %%
pipeline(X_all, y_all, "RandomForestClassifier", "all", "kbest")
# Out:
# Accuracy = 0.66
# F1 = 0.42
# ROC_AUC = 0.71

# %%
pipeline(X_all, y_all, "XGBoostClassifier", "all", "kbest")
# Out:
# Accuracy = 0.66
# F1 = 0.42
# ROC_AUC = 0.66

# %%
pipeline(X_all, y_all, "CatBoostClassifier", "all", "kbest")
# Out:
# Accuracy = 0.62
# F1 = 0.33
# ROC_AUC = 0.61
# 0:	learn: 0.6283701	total: 1.81ms	remaining: 116ms
# 1:	learn: 0.6053911	total: 3.63ms	remaining: 114ms
# 2:	learn: 0.5686848	total: 6.08ms	remaining: 126ms
# 3:	learn: 0.5642031	total: 8ms	remaining: 122ms
# 4:	learn: 0.5501462	total: 10ms	remaining: 121ms
# 5:	learn: 0.5348380	total: 11.5ms	remaining: 113ms
# 6:	learn: 0.5277759	total: 13.2ms	remaining: 110ms
# 7:	learn: 0.5051670	total: 14.6ms	remaining: 104ms
# 8:	learn: 0.4841840	total: 16.1ms	remaining: 99.9ms
# 9:	learn: 0.4615403	total: 17.8ms	remaining: 97.8ms
# 10:	learn: 0.4352224	total: 19.7ms	remaining: 96.5ms
# 11:	learn: 0.4266954	total: 21.9ms	remaining: 96.5ms
# 12:	learn: 0.4073219	total: 23.7ms	remaining: 94.9ms
# 13:	learn: 0.3819430	total: 25.4ms	remaining: 92.3ms
# 14:	learn: 0.3622100	total: 27.1ms	remaining: 90.2ms
# 15:	learn: 0.3539740	total: 28.7ms	remaining: 87.8ms
# 16:	learn: 0.3373530	total: 30.8ms	remaining: 86.9ms
# 17:	learn: 0.3301510	total: 32.6ms	remaining: 85.2ms
# 18:	learn: 0.3224780	total: 34.5ms	remaining: 83.6ms
# 19:	learn: 0.3197148	total: 36.2ms	remaining: 81.4ms
# 20:	learn: 0.3060863	total: 37.5ms	remaining: 78.6ms
# 21:	learn: 0.2852902	total: 38.9ms	remaining: 76.1ms
# 22:	learn: 0.2778071	total: 40.6ms	remaining: 74.1ms
# 23:	learn: 0.2636624	total: 42ms	remaining: 71.7ms
# 24:	learn: 0.2549696	total: 43.3ms	remaining: 69.3ms
# 25:	learn: 0.2376001	total: 44.6ms	remaining: 66.8ms
# 26:	learn: 0.2330413	total: 45.8ms	remaining: 64.5ms
# 27:	learn: 0.2299763	total: 47.2ms	remaining: 62.4ms
# 28:	learn: 0.2206554	total: 48.7ms	remaining: 60.5ms
# 29:	learn: 0.2162286	total: 50.1ms	remaining: 58.4ms
# 30:	learn: 0.2102708	total: 51.5ms	remaining: 56.5ms
# 31:	learn: 0.1991400	total: 52.9ms	remaining: 54.5ms
# 32:	learn: 0.1969248	total: 54.3ms	remaining: 52.7ms
# 33:	learn: 0.1880459	total: 55.6ms	remaining: 50.7ms
# 34:	learn: 0.1795150	total: 56.9ms	remaining: 48.8ms
# 35:	learn: 0.1726589	total: 58.3ms	remaining: 46.9ms
# 36:	learn: 0.1669035	total: 59.5ms	remaining: 45ms
# 37:	learn: 0.1608337	total: 60.9ms	remaining: 43.3ms
# 38:	learn: 0.1524062	total: 62.3ms	remaining: 41.6ms
# 39:	learn: 0.1452877	total: 63.7ms	remaining: 39.8ms
# 40:	learn: 0.1406657	total: 65.1ms	remaining: 38.1ms
# 41:	learn: 0.1379276	total: 66.6ms	remaining: 36.4ms
# 42:	learn: 0.1320560	total: 67.9ms	remaining: 34.8ms
# 43:	learn: 0.1271410	total: 69.2ms	remaining: 33ms
# 44:	learn: 0.1208959	total: 70.6ms	remaining: 31.4ms
# 45:	learn: 0.1194291	total: 72ms	remaining: 29.7ms
# 46:	learn: 0.1156109	total: 73.5ms	remaining: 28.1ms
# 47:	learn: 0.1120070	total: 74.9ms	remaining: 26.5ms
# 48:	learn: 0.1100325	total: 76.5ms	remaining: 25ms
# 49:	learn: 0.1050934	total: 77.8ms	remaining: 23.3ms
# 50:	learn: 0.1016088	total: 79.2ms	remaining: 21.7ms
# 51:	learn: 0.0976851	total: 80.6ms	remaining: 20.1ms
# 52:	learn: 0.0957543	total: 82.2ms	remaining: 18.6ms
# 53:	learn: 0.0917120	total: 83.7ms	remaining: 17ms
# 54:	learn: 0.0853699	total: 85.1ms	remaining: 15.5ms
# 55:	learn: 0.0827240	total: 86.5ms	remaining: 13.9ms
# 56:	learn: 0.0798519	total: 87.9ms	remaining: 12.3ms
# 57:	learn: 0.0762792	total: 89.2ms	remaining: 10.8ms
# 58:	learn: 0.0752186	total: 90.6ms	remaining: 9.21ms
# 59:	learn: 0.0735930	total: 91.9ms	remaining: 7.66ms
# 60:	learn: 0.0726103	total: 93.4ms	remaining: 6.12ms
# 61:	learn: 0.0702839	total: 94.8ms	remaining: 4.59ms
# 62:	learn: 0.0690900	total: 96.2ms	remaining: 3.06ms
# 63:	learn: 0.0678110	total: 97.6ms	remaining: 1.52ms
# 64:	learn: 0.0676925	total: 98.9ms	remaining: 0us

# %%
pipeline(X_all, y_all, "RidgeLogistic", "all", "kbest")
# Out:
# Accuracy = 0.62
# F1 = 0.5
# ROC_AUC = 0.65

# %% [markdown]
# MODELING - NATIVE CONTRAST

# %%
pipeline(X_native, y_all, "RandomForestClassifier", "native", "kbest")
# Out:
# Accuracy = 0.62
# F1 = 0.45
# ROC_AUC = 0.58

# %%
pipeline(X_native, y_all, "XGBoostClassifier", "native", "kbest")
# Out:
# Accuracy = 0.62
# F1 = 0.25
# ROC_AUC = 0.55

# %%
pipeline(X_native, y_all, "CatBoostClassifier", "native", "kbest")
# Out:
# Accuracy = 0.66
# F1 = 0
# 143:	learn: 0.0040816	total: 2m 25s	remaining: 2m 18s
# 144:	learn: 0.0040324	total: 2m 26s	remaining: 2m 17s
# 145:	learn: 0.0040038	total: 2m 28s	remaining: 2m 17s
# 146:	learn: 0.0039800	total: 2m 29s	remaining: 2m 16s
# 147:	learn: 0.0039367	total: 2m 30s	remaining: 2m 15s
# 148:	learn: 0.0039160	total: 2m 31s	remaining: 2m 13s
# 149:	learn: 0.0038774	total: 2m 32s	remaining: 2m 12s
# 150:	learn: 0.0038380	total: 2m 32s	remaining: 2m 11s
# 151:	learn: 0.0038098	total: 2m 33s	remaining: 2m 10s
# 152:	learn: 0.0037844	total: 2m 34s	remaining: 2m 9s
# 153:	learn: 0.0037525	total: 2m 35s	remaining: 2m 8s
# 154:	learn: 0.0037308	total: 2m 36s	remaining: 2m 7s
# 155:	learn: 0.0036740	total: 2m 37s	remaining: 2m 6s
# 156:	learn: 0.0036381	total: 2m 38s	remaining: 2m 4s
# 157:	learn: 0.0036016	total: 2m 39s	remaining: 2m 3s
# 158:	learn: 0.0035764	total: 2m 39s	remaining: 2m 2s
# 159:	learn: 0.0035470	total: 2m 40s	remaining: 2m 1s
# 160:	learn: 0.0035214	total: 2m 41s	remaining: 2m
# 161:	learn: 0.0034961	total: 2m 42s	remaining: 1m 59s
# 162:	learn: 0.0034750	total: 2m 43s	remaining: 1m 58s
# 163:	learn: 0.0034426	total: 2m 44s	remaining: 1m 57s
# 164:	learn: 0.0034174	total: 2m 45s	remaining: 1m 56s
# 165:	learn: 0.0033956	total: 2m 45s	remaining: 1m 54s
# 166:	learn: 0.0033640	total: 2m 46s	remaining: 1m 53s
# 167:	learn: 0.0033440	total: 2m 47s	remaining: 1m 52s
# 168:	learn: 0.0033232	total: 2m 48s	remaining: 1m 51s
# 169:	learn: 0.0033082	total: 2m 49s	remaining: 1m 50s
# 170:	learn: 0.0032897	total: 2m 50s	remaining: 1m 49s
# 171:	learn: 0.0032714	total: 2m 51s	remaining: 1m 48s
# 172:	learn: 0.0032528	total: 2m 52s	remaining: 1m 47s
# 173:	learn: 0.0032318	total: 2m 52s	remaining: 1m 46s
# 174:	learn: 0.0032095	total: 2m 53s	remaining: 1m 45s
# 175:	learn: 0.0031917	total: 2m 54s	remaining: 1m 44s
# 176:	learn: 0.0031708	total: 2m 55s	remaining: 1m 43s
# 177:	learn: 0.0031501	total: 2m 56s	remaining: 1m 42s
# 178:	learn: 0.0031213	total: 2m 57s	remaining: 1m 40s
# 179:	learn: 0.0031087	total: 2m 58s	remaining: 1m 39s
# 180:	learn: 0.0030908	total: 2m 58s	remaining: 1m 38s
# 181:	learn: 0.0030766	total: 2m 59s	remaining: 1m 37s
# 182:	learn: 0.0030610	total: 3m	remaining: 1m 36s
# 183:	learn: 0.0030432	total: 3m 1s	remaining: 1m 35s
# 184:	learn: 0.0030246	total: 3m 2s	remaining: 1m 34s
# 185:	learn: 0.0030075	total: 3m 3s	remaining: 1m 33s
# 186:	learn: 0.0029870	total: 3m 3s	remaining: 1m 32s
# 187:	learn: 0.0029668	total: 3m 4s	remaining: 1m 31s
# 188:	learn: 0.0029436	total: 3m 5s	remaining: 1m 30s
# 189:	learn: 0.0029258	total: 3m 6s	remaining: 1m 29s
# 190:	learn: 0.0029094	total: 3m 7s	remaining: 1m 28s
# 191:	learn: 0.0028952	total: 3m 8s	remaining: 1m 27s
# 192:	learn: 0.0028810	total: 3m 8s	remaining: 1m 26s
# 193:	learn: 0.0028596	total: 3m 9s	remaining: 1m 25s
# 194:	learn: 0.0028424	total: 3m 10s	remaining: 1m 24s
# 195:	learn: 0.0028203	total: 3m 11s	remaining: 1m 23s
# 196:	learn: 0.0028035	total: 3m 12s	remaining: 1m 22s
# 197:	learn: 0.0027848	total: 3m 13s	remaining: 1m 21s
# 198:	learn: 0.0027730	total: 3m 14s	remaining: 1m 19s
# 199:	learn: 0.0027541	total: 3m 14s	remaining: 1m 18s
# 200:	learn: 0.0027375	total: 3m 15s	remaining: 1m 17s
# 201:	learn: 0.0027249	total: 3m 16s	remaining: 1m 16s
# 202:	learn: 0.0027105	total: 3m 17s	remaining: 1m 15s
# 203:	learn: 0.0027006	total: 3m 18s	remaining: 1m 14s
# 204:	learn: 0.0026854	total: 3m 19s	remaining: 1m 13s
# 205:	learn: 0.0026721	total: 3m 20s	remaining: 1m 12s
# 206:	learn: 0.0026592	total: 3m 20s	remaining: 1m 11s
# 207:	learn: 0.0026518	total: 3m 21s	remaining: 1m 10s
# 208:	learn: 0.0026400	total: 3m 22s	remaining: 1m 9s
# 209:	learn: 0.0026115	total: 3m 23s	remaining: 1m 8s
# 210:	learn: 0.0025980	total: 3m 24s	remaining: 1m 7s
# 211:	learn: 0.0025814	total: 3m 25s	remaining: 1m 6s
# 212:	learn: 0.0025661	total: 3m 26s	remaining: 1m 5s
# 213:	learn: 0.0025523	total: 3m 27s	remaining: 1m 4s
# 214:	learn: 0.0025419	total: 3m 27s	remaining: 1m 3s
# 215:	learn: 0.0025276	total: 3m 28s	remaining: 1m 2s
# 216:	learn: 0.0025101	total: 3m 29s	remaining: 1m 1s
# 217:	learn: 0.0024971	total: 3m 30s	remaining: 1m
# 218:	learn: 0.0024820	total: 3m 31s	remaining: 59.8s
# 219:	learn: 0.0024682	total: 3m 32s	remaining: 58.8s
# 220:	learn: 0.0024597	total: 3m 33s	remaining: 57.9s
# 221:	learn: 0.0024490	total: 3m 33s	remaining: 56.9s
# 222:	learn: 0.0024347	total: 3m 34s	remaining: 55.9s
# 223:	learn: 0.0024195	total: 3m 35s	remaining: 54.9s
# 224:	learn: 0.0024112	total: 3m 36s	remaining: 53.9s
# 225:	learn: 0.0023996	total: 3m 37s	remaining: 52.9s
# 226:	learn: 0.0023841	total: 3m 38s	remaining: 51.9s
# 227:	learn: 0.0023726	total: 3m 39s	remaining: 50.9s
# 228:	learn: 0.0023628	total: 3m 39s	remaining: 50s
# 229:	learn: 0.0023512	total: 3m 40s	remaining: 49s
# 230:	learn: 0.0023367	total: 3m 41s	remaining: 48s
# 231:	learn: 0.0023260	total: 3m 42s	remaining: 47s
# 232:	learn: 0.0023163	total: 3m 43s	remaining: 46s
# 233:	learn: 0.0023027	total: 3m 44s	remaining: 45.1s
# 234:	learn: 0.0022932	total: 3m 45s	remaining: 44.1s
# 235:	learn: 0.0022864	total: 3m 46s	remaining: 43.1s
# 236:	learn: 0.0022793	total: 3m 46s	remaining: 42.1s
# 237:	learn: 0.0022687	total: 3m 47s	remaining: 41.2s
# 238:	learn: 0.0022563	total: 3m 48s	remaining: 40.2s
# 239:	learn: 0.0022431	total: 3m 49s	remaining: 39.2s
# 240:	learn: 0.0022328	total: 3m 50s	remaining: 38.3s
# 241:	learn: 0.0022253	total: 3m 51s	remaining: 37.3s
# 242:	learn: 0.0022148	total: 3m 52s	remaining: 36.3s
# 243:	learn: 0.0022051	total: 3m 53s	remaining: 35.3s
# 244:	learn: 0.0021981	total: 3m 53s	remaining: 34.4s
# 245:	learn: 0.0021873	total: 3m 54s	remaining: 33.4s
# 246:	learn: 0.0021792	total: 3m 55s	remaining: 32.4s
# 247:	learn: 0.0021701	total: 3m 56s	remaining: 31.5s
# 248:	learn: 0.0021583	total: 3m 57s	remaining: 30.5s
# 249:	learn: 0.0021517	total: 3m 58s	remaining: 29.5s
# 250:	learn: 0.0021406	total: 3m 59s	remaining: 28.6s
# 251:	learn: 0.0021314	total: 3m 59s	remaining: 27.6s
# 252:	learn: 0.0021219	total: 4m	remaining: 26.7s
# 253:	learn: 0.0021004	total: 4m 1s	remaining: 25.7s
# 254:	learn: 0.0020879	total: 4m 2s	remaining: 24.7s
# 255:	learn: 0.0020815	total: 4m 3s	remaining: 23.8s
# 256:	learn: 0.0020702	total: 4m 4s	remaining: 22.8s
# 257:	learn: 0.0020619	total: 4m 5s	remaining: 21.9s
# 258:	learn: 0.0020534	total: 4m 5s	remaining: 20.9s
# 259:	learn: 0.0020476	total: 4m 6s	remaining: 19.9s
# 260:	learn: 0.0020366	total: 4m 7s	remaining: 19s
# 261:	learn: 0.0020254	total: 4m 8s	remaining: 18s
# 262:	learn: 0.0020151	total: 4m 9s	remaining: 17.1s
# 263:	learn: 0.0020037	total: 4m 10s	remaining: 16.1s
# 264:	learn: 0.0019977	total: 4m 11s	remaining: 15.2s
# 265:	learn: 0.0019877	total: 4m 11s	remaining: 14.2s
# 266:	learn: 0.0019755	total: 4m 12s	remaining: 13.3s
# 267:	learn: 0.0019707	total: 4m 13s	remaining: 12.3s
# 268:	learn: 0.0019596	total: 4m 14s	remaining: 11.4s
# 269:	learn: 0.0019539	total: 4m 15s	remaining: 10.4s
# 270:	learn: 0.0019475	total: 4m 16s	remaining: 9.46s
# 271:	learn: 0.0019404	total: 4m 17s	remaining: 8.51s
# 272:	learn: 0.0019355	total: 4m 18s	remaining: 7.56s
# 273:	learn: 0.0019273	total: 4m 18s	remaining: 6.61s
# 274:	learn: 0.0019187	total: 4m 19s	remaining: 5.67s
# 275:	learn: 0.0019107	total: 4m 20s	remaining: 4.72s
# 276:	learn: 0.0019031	total: 4m 21s	remaining: 3.77s
# 277:	learn: 0.0018989	total: 4m 22s	remaining: 2.83s
# 278:	learn: 0.0018876	total: 4m 23s	remaining: 1.89s
# 279:	learn: 0.0018780	total: 4m 24s	remaining: 943ms
# 280:	learn: 0.0018690	total: 4m 24s	remaining: 0us

# %%
pipeline(X_native, y_all, "RidgeLogistic", "native", "kbest")
# Out:
# Accuracy = 0.66
# F1 = 0.35
# ROC_AUC = 0.62
